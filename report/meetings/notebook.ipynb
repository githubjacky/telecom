# %% [markdown]
# A Demo to run jupyter notebook

# %%
# connect to GPU
from dask_cuda import LocalCUDACluster
from dask.distributed import Client
import dask

import os
os.chdir('../../')

cluster = LocalCUDACluster(
    CUDA_VISIBLE_DEVICES="0,1",
    protocol="ucx",
    enable_tcp_over_ucx=True,
    enable_infiniband=True,
    rmm_managed_memory=True,
    rmm_pool_size='24GB'
)
client = Client(cluster)

dask.config.set({"dataframe.backend": "cudf"})

from src.process.utils import CallDistanceUtil
driver = CallDistanceUtil()

# %%
user_info = driver.get_user_info(target='communication', method = 'mean')
# Out:
# /usr/local/lib/python3.10/site-packages/cudf/core/index.py:3369: FutureWarning: cudf.StringIndex is deprecated and will be removed from cudf in a future version. Use cudf.Index with the appropriate dtype instead.
#   warnings.warn(
# /usr/local/lib/python3.10/site-packages/cudf/core/index.py:3369: FutureWarning: cudf.StringIndex is deprecated and will be removed from cudf in a future version. Use cudf.Index with the appropriate dtype instead.
#   warnings.warn(
# /usr/local/lib/python3.10/site-packages/cupy/cuda/compiler.py:233: PerformanceWarning: Jitify is performing a one-time only warm-up to populate the persistent cache, this may take a few seconds and will be improved in a future release...
#   jitify._init_module()
# /usr/local/lib/python3.10/site-packages/distributed/client.py:3162: UserWarning: Sending large graph of size 10.79 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(

# %%
list(user_info.columns)
# Out:
# ['client_nbr',
#  'mean_communication_distance',
#  'serv_id',
#  'born_area_code',
#  'register_district',
#  'age',
#  'male_flag',
#  'tenure',
#  'phone_brand',
#  'phone_level',
#  'phone_price',
#  'evdo_support_flag',
#  'arpu',
#  'mou_total',
#  'mou_local_callout',
#  'mou_dist_callout',
#  'network_usage_time',
#  'use_evdo_flag',
#  'use_onex_flag',
#  'e9_service_flag',
#  'e6_service_flag',
#  'e9_service_premium_flag',
#  '8card_service_flag',
#  'smart_phone_flag',
#  'govern_worker_flag',
#  'business_purpose_flag',
#  'red_mark_flag',
#  'govern_cluster_flag',
#  'govern_industry_flag',
#  'vpn_support_flag']

# %%
import statsmodels.formula.api as smf
import pandas as pd

# %%
def encode_born_area_code(x):
    x_ = x // 100

    match x_:
        case 5106:
            return '德阳市'
        case 5101:
            return '成都市'
        case 5107:
            return '绵阳市'
        case 5110:
            return '内江市'
        case 5109:
            return '遂宁市'
        case 5130:
            return '已撤銷_达川地区'
        case 5102:
            return '已撤銷_乐山市市辖区'
        case 5108:
            return '广元市'
        case 5113:
            return '南充市'
        case 5129:
            return '已撤銷_南充地区'
        case 5103:
            return '自贡市'
        case 5111:
            return '乐山市'
        case 5131:
            return '已撤銷_雅安地區'
        case 5105:
            return '泸州市'
        case 5134:
            return '凉山彝族自治州'
        case 5139:
            return '已撤銷_眉山地区资阳地区'
        case 5137:
            return '已撤銷_巴中地區'
        case 5002:
            return '重慶市城口县'
        case 5138:
            return '已撤銷_眉山地区'
        case 5132:
            return '阿坝藏族羌族自治州'
        case 5125:
            return'已撤銷_宜宾市'
        case 5115:
            return '宜宾市'
        case 5116:
            return '广安市'
        case 5122:
            return '已撤銷_万县市'
        case 5104:
            return '攀枝花市'
        case 5133:
            return '甘孜藏族自治州'
        case 3303:
            return '浙江省温州市'
        case 6328:
            return '青海省海西蒙古族藏族自治州'
        case _:
            return '其他'

df = (
    user_info
    .born_area_code
    .apply(encode_born_area_code)
    .value_counts()[:26]
    .reset_index()
)
df['ratio'] = df['born_area_code'].apply(lambda x: x*100/user_info.shape[0])
df.rename(columns={'born_area_code': 'count'})
# Out:
#             index  count      ratio
# 0             德阳市  56085  84.906517
# 1              其他   2061   3.120127
# 2             绵阳市   1389   2.102793
# 3             成都市   1178   1.783362
# 4             内江市    927   1.403376
# 5             遂宁市    645   0.976459
# 6      已撤銷_乐山市市辖区    434   0.657028
# 7        已撤銷_雅安地區    346   0.523806
# 8             广元市    330   0.499584
# 9        已撤銷_达川地区    313   0.473848
# 10       已撤銷_南充地区    288   0.436000
# 11            乐山市    278   0.420861
# 12            自贡市    205   0.310347
# 13            泸州市    197   0.298236
# 14            南充市    196   0.296722
# 15        凉山彝族自治州    171   0.258875
# 16        已撤銷_万县市    105   0.158958
# 17      阿坝藏族羌族自治州    100   0.151389
# 18         重慶市城口县     93   0.140792
# 19   已撤銷_眉山地区资阳地区     89   0.134736
# 20        已撤銷_宜宾市     85   0.128681
# 21       已撤銷_巴中地區     83   0.125653
# 22        甘孜藏族自治州     81   0.122625
# 23         浙江省温州市     80   0.121111
# 24           攀枝花市     79   0.119597
# 25  青海省海西蒙古族藏族自治州     67   0.101431

# %%
user_info['born_area'] = user_info['born_area_code'].apply(encode_born_area_code)

# %%
data = (
        user_info[[
            'age', 'male_flag', 'tenure', 'business_purpose_flag', 'smart_phone_flag',
            'govern_worker_flag', 'govern_cluster_flag', 'govern_industry_flag',
            'register_district', 'born_area', 'mean_communication_distance'
        ]]
        .join([
            # compare to 中端
            pd.get_dummies(user_info['phone_level'], drop_first=True),
            # compare to 德阳现业
            # pd.get_dummies(user_info['register_district'], prefix='註冊地'),
            # pd.get_dummies(user_info['born_area'], prefix='出生地')

        ])
)

formula = """\
    mean_communication_distance ~ age + male_flag + tenure + \
        business_purpose_flag + smart_phone_flag + govern_worker_flag + \
        govern_cluster_flag + govern_industry_flag + 低端 + 超低端 + 超高端 + \
        高端 + register_district:born_area\
"""
smf.ols(formula, data=data).fit(cov_type='HC0').summary()
# Out:
# /usr/local/lib/python3.10/site-packages/statsmodels/base/model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 53, but rank is 50
#   warnings.warn('covariance of constraints does not have full '
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:     mean_communication_distance   R-squared:                       0.012
# Model:                                     OLS   Adj. R-squared:                  0.011
# Method:                          Least Squares   F-statistic:                     3728.
# Date:                         Mon, 29 Apr 2024   Prob (F-statistic):               0.00
# Time:                                 06:52:01   Log-Likelihood:            -3.2102e+05
# No. Observations:                        66055   AIC:                         6.422e+05
# Df Residuals:                            66004   BIC:                         6.426e+05
# Df Model:                                   50
# Covariance Type:                           HC0
# ======================================================================================================================
#                                                          coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# Intercept                                             13.6661      0.917     14.900      0.000      11.868      15.464
# born_area[T.凉山彝族自治州]                                   2.4215      7.072      0.342      0.732     -11.440      16.283
# born_area[T.已撤銷_眉山地区]                                 -7.6044      1.943     -3.914      0.000     -11.412      -3.797
# born_area[T.攀枝花市]                                     45.8640     27.701      1.656      0.098      -8.429     100.157
# born_area[T.浙江省温州市]                                    1.6195      7.946      0.204      0.839     -13.955      17.194
# born_area[T.甘孜藏族自治州]                                  -6.1333      2.164     -2.834      0.005     -10.375      -1.891
# born_area[T.青海省海西蒙古族藏族自治州]                            -8.1514      1.610     -5.062      0.000     -11.307      -4.995
# register_district[T.什邡]:born_area[其他]                 -2.1508      0.450     -4.780      0.000      -3.033      -1.269
# register_district[T.广汉]:born_area[其他]                 -1.0739      0.425     -2.525      0.012      -1.908      -0.240
# register_district[T.德阳现业]:born_area[其他]               -1.2381      0.381     -3.249      0.001      -1.985      -0.491
# register_district[T.绵竹]:born_area[其他]                 -1.3374      0.460     -2.909      0.004      -2.239      -0.436
# register_district[T.罗江]:born_area[其他]                 -1.6008      0.567     -2.821      0.005      -2.713      -0.489
# register_district[T.什邡]:born_area[凉山彝族自治州]           -11.2530      7.090     -1.587      0.112     -25.149       2.643
# register_district[T.广汉]:born_area[凉山彝族自治州]            10.8970     13.912      0.783      0.433     -16.370      38.164
# register_district[T.德阳现业]:born_area[凉山彝族自治州]          39.7066     14.564      2.726      0.006      11.162      68.251
# register_district[T.绵竹]:born_area[凉山彝族自治州]           -10.6316      7.212     -1.474      0.140     -24.768       3.504
# register_district[T.罗江]:born_area[凉山彝族自治州]             8.4968     19.981      0.425      0.671     -30.666      47.659
# register_district[T.什邡]:born_area[已撤銷_眉山地区]           -2.4165      1.990     -1.215      0.225      -6.316       1.483
# register_district[T.广汉]:born_area[已撤銷_眉山地区]            9.8309      7.865      1.250      0.211      -5.585      25.247
# register_district[T.德阳现业]:born_area[已撤銷_眉山地区]         54.0458     20.451      2.643      0.008      13.962      94.130
# register_district[T.绵竹]:born_area[已撤銷_眉山地区]           62.3249     49.746      1.253      0.210     -35.175     159.825
# register_district[T.罗江]:born_area[已撤銷_眉山地区]         2.487e-15   1.35e-14      0.184      0.854    -2.4e-14     2.9e-14
# register_district[T.什邡]:born_area[攀枝花市]              -44.9726     28.223     -1.593      0.111    -100.289      10.344
# register_district[T.广汉]:born_area[攀枝花市]              -22.8012     36.375     -0.627      0.531     -94.095      48.493
# register_district[T.德阳现业]:born_area[攀枝花市]            -41.1288     28.157     -1.461      0.144     -96.316      14.058
# register_district[T.绵竹]:born_area[攀枝花市]              -55.6769     27.713     -2.009      0.045    -109.993      -1.361
# register_district[T.罗江]:born_area[攀枝花市]              210.4436    136.265      1.544      0.122     -56.631     477.518
# register_district[T.什邡]:born_area[浙江省温州市]            -10.8341      7.966     -1.360      0.174     -26.447       4.779
# register_district[T.广汉]:born_area[浙江省温州市]             -9.8686      8.063     -1.224      0.221     -25.673       5.935
# register_district[T.德阳现业]:born_area[浙江省温州市]           -5.9035      8.260     -0.715      0.475     -22.093      10.286
# register_district[T.绵竹]:born_area[浙江省温州市]            -11.1402      7.943     -1.403      0.161     -26.708       4.428
# register_district[T.罗江]:born_area[浙江省温州市]             -8.4470      8.501     -0.994      0.320     -25.109       8.215
# register_district[T.什邡]:born_area[甘孜藏族自治州]            53.2941     30.849      1.728      0.084      -7.170     113.758
# register_district[T.广汉]:born_area[甘孜藏族自治州]            33.8705     24.134      1.403      0.160     -13.432      81.173
# register_district[T.德阳现业]:born_area[甘孜藏族自治州]          44.6470     17.652      2.529      0.011      10.050      79.244
# register_district[T.绵竹]:born_area[甘孜藏族自治州]            84.7550     66.146      1.281      0.200     -44.890     214.400
# register_district[T.罗江]:born_area[甘孜藏族自治州]           152.5554    109.025      1.399      0.162     -61.130     366.241
# register_district[T.什邡]:born_area[青海省海西蒙古族藏族自治州]       0.0517      1.614      0.032      0.974      -3.112       3.215
# register_district[T.广汉]:born_area[青海省海西蒙古族藏族自治州]       0.8233      1.720      0.479      0.632      -2.548       4.195
# register_district[T.德阳现业]:born_area[青海省海西蒙古族藏族自治州]     1.2798      1.934      0.662      0.508      -2.511       5.070
# register_district[T.绵竹]:born_area[青海省海西蒙古族藏族自治州]   -3.031e-14    9.9e-15     -3.062      0.002   -4.97e-14   -1.09e-14
# register_district[T.罗江]:born_area[青海省海西蒙古族藏族自治州]      41.7268      1.635     25.528      0.000      38.523      44.931
# age                                                   -0.0747      0.011     -6.762      0.000      -0.096      -0.053
# male_flag                                              0.3433      0.254      1.351      0.177      -0.155       0.842
# tenure                                                -0.0101      0.001     -7.298      0.000      -0.013      -0.007
# business_purpose_flag                                 -0.9737      0.480     -2.031      0.042      -1.913      -0.034
# smart_phone_flag                                       1.0132      0.336      3.013      0.003       0.354       1.672
# govern_worker_flag                                    -0.5470      0.253     -2.162      0.031      -1.043      -0.051
# govern_cluster_flag                                   -1.2816      0.844     -1.518      0.129      -2.936       0.373
# govern_industry_flag                                  -1.0810      0.595     -1.817      0.069      -2.247       0.085
# 低端                                                    -0.6343      0.332     -1.913      0.056      -1.284       0.016
# 超低端                                                    0.1089      0.429      0.254      0.800      -0.731       0.949
# 超高端                                                    3.0018      1.212      2.477      0.013       0.627       5.377
# 高端                                                     0.8603      0.580      1.484      0.138      -0.276       1.997
# ==============================================================================
# Omnibus:                   100692.134   Durbin-Watson:                   1.912
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         44371575.994
# Skew:                           9.706   Prob(JB):                         0.00
# Kurtosis:                     128.479   Cond. No.                     1.39e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC0)
# [2] The smallest eigenvalue is 3.58e-24. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
def simple_encode_born_area_code(x):
    x_ = x // 100
    
    match x_:
        case 5133:
            return '甘孜藏族自治州'
        case 5134:
            return '凉山彝族自治州'
        case 5138:
            return '已撤銷_眉山地区'
        case 6328:
            return '青海省海西蒙古族藏族自治州'
        case _:
            return '其他'

user_info['born_area'] = user_info['born_area_code'].apply(simple_encode_born_area_code)

data = (
    user_info[[
        'age', 'male_flag', 'tenure', 'business_purpose_flag', 'smart_phone_flag',
        'govern_worker_flag', 'govern_cluster_flag', 'govern_industry_flag',
        'register_district', 'born_area', 'mean_communication_distance'
    ]]
    .join([
        # compare to 中端
        pd.get_dummies(user_info['phone_level'], drop_first=True),

    ])
)
formula = """\
    mean_communication_distance ~ age + male_flag + tenure + \
        business_purpose_flag + smart_phone_flag + govern_worker_flag + \
        govern_cluster_flag + govern_industry_flag + 低端 + 超低端 + 超高端 + \
        高端 + C(born_area):C(register_district)\
"""
(
    smf.ols(
        formula,
        data=data,
    )
    .fit(cov_type='HC0')
    .summary()
)
# Out:
# /usr/local/lib/python3.10/site-packages/statsmodels/base/model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 41, but rank is 39
#   warnings.warn('covariance of constraints does not have full '
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:     mean_communication_distance   R-squared:                       0.009
# Model:                                     OLS   Adj. R-squared:                  0.009
# Method:                          Least Squares   F-statistic:                     3862.
# Date:                         Mon, 29 Apr 2024   Prob (F-statistic):               0.00
# Time:                                 06:56:41   Log-Likelihood:            -3.2110e+05
# No. Observations:                        66055   AIC:                         6.423e+05
# Df Residuals:                            66015   BIC:                         6.426e+05
# Df Model:                                   39
# Covariance Type:                           HC0
# ============================================================================================================================
#                                                                coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------
# Intercept                                                   13.7527      0.930     14.793      0.000      11.931      15.575
# C(register_district)[T.什邡]                                  -2.1565      0.450     -4.797      0.000      -3.038      -1.275
# C(register_district)[T.广汉]                                  -1.0528      0.427     -2.468      0.014      -1.889      -0.217
# C(register_district)[T.德阳现业]                                -1.2302      0.381     -3.230      0.001      -1.977      -0.484
# C(register_district)[T.绵竹]                                  -1.3468      0.460     -2.931      0.003      -2.247      -0.446
# C(register_district)[T.罗江]                                  -1.4862      0.580     -2.564      0.010      -2.622      -0.350
# C(born_area)[T.凉山彝族自治州]:C(register_district)[中江]             2.4108      7.071      0.341      0.733     -11.447      16.269
# C(born_area)[T.已撤銷_眉山地区]:C(register_district)[中江]           -7.6026      1.949     -3.901      0.000     -11.423      -3.783
# C(born_area)[T.甘孜藏族自治州]:C(register_district)[中江]            -6.1280      2.162     -2.834      0.005     -10.365      -1.891
# C(born_area)[T.青海省海西蒙古族藏族自治州]:C(register_district)[中江]      -8.1421      1.621     -5.021      0.000     -11.320      -4.964
# C(born_area)[T.凉山彝族自治州]:C(register_district)[什邡]            -6.6760      0.669     -9.972      0.000      -7.988      -5.364
# C(born_area)[T.已撤銷_眉山地区]:C(register_district)[什邡]           -7.8899      0.623    -12.655      0.000      -9.112      -6.668
# C(born_area)[T.甘孜藏族自治州]:C(register_district)[什邡]            49.3158     30.777      1.602      0.109     -11.006     109.637
# C(born_area)[T.青海省海西蒙古族藏族自治州]:C(register_district)[什邡]      -5.9279      0.453    -13.078      0.000      -6.816      -5.040
# C(born_area)[T.凉山彝族自治州]:C(register_district)[广汉]            14.3770     11.991      1.199      0.231      -9.126      37.880
# C(born_area)[T.已撤銷_眉山地区]:C(register_district)[广汉]            3.2690      7.636      0.428      0.669     -11.698      18.236
# C(born_area)[T.甘孜藏族自治州]:C(register_district)[广汉]            28.7956     24.041      1.198      0.231     -18.325      75.916
# C(born_area)[T.青海省海西蒙古族藏族自治州]:C(register_district)[广汉]      -6.2896      0.763     -8.240      0.000      -7.786      -4.793
# C(born_area)[T.凉山彝族自治州]:C(register_district)[德阳现业]          43.3447     12.738      3.403      0.001      18.378      68.311
# C(born_area)[T.已撤銷_眉山地区]:C(register_district)[德阳现业]         47.6409     20.360      2.340      0.019       7.736      87.546
# C(born_area)[T.甘孜藏族自治州]:C(register_district)[德阳现业]          39.7313     17.529      2.267      0.023       5.374      74.088
# C(born_area)[T.青海省海西蒙古族藏族自治州]:C(register_district)[德阳现业]    -5.6521      1.143     -4.945      0.000      -7.892      -3.412
# C(born_area)[T.凉山彝族自治州]:C(register_district)[绵竹]            -6.8588      1.502     -4.567      0.000      -9.802      -3.915
# C(born_area)[T.已撤銷_眉山地区]:C(register_district)[绵竹]           56.0601     49.713      1.128      0.259     -41.375     153.495
# C(born_area)[T.甘孜藏族自治州]:C(register_district)[绵竹]            79.9452     66.092      1.210      0.226     -49.592     209.482
# C(born_area)[T.青海省海西蒙古族藏族自治州]:C(register_district)[绵竹]   -1.982e-14   2.67e-14     -0.741      0.459   -7.22e-14    3.26e-14
# C(born_area)[T.凉山彝族自治州]:C(register_district)[罗江]            12.3789     18.695      0.662      0.508     -24.263      49.021
# C(born_area)[T.已撤銷_眉山地区]:C(register_district)[罗江]        -5.297e-14   3.34e-14     -1.585      0.113   -1.18e-13    1.25e-14
# C(born_area)[T.甘孜藏族自治州]:C(register_district)[罗江]           147.8512    109.008      1.356      0.175     -65.800     361.502
# C(born_area)[T.青海省海西蒙古族藏族自治州]:C(register_district)[罗江]      35.0460      0.584     60.050      0.000      33.902      36.190
# age                                                         -0.0749      0.011     -6.770      0.000      -0.097      -0.053
# male_flag                                                    0.3204      0.255      1.256      0.209      -0.179       0.820
# tenure                                                      -0.0102      0.001     -7.304      0.000      -0.013      -0.007
# business_purpose_flag                                       -0.9761      0.479     -2.036      0.042      -1.916      -0.036
# smart_phone_flag                                             1.0010      0.337      2.967      0.003       0.340       1.662
# govern_worker_flag                                          -0.5309      0.253     -2.095      0.036      -1.028      -0.034
# govern_cluster_flag                                         -1.3716      0.851     -1.611      0.107      -3.040       0.297
# govern_industry_flag                                        -1.1418      0.605     -1.888      0.059      -2.327       0.043
# 低端                                                          -0.6434      0.332     -1.937      0.053      -1.294       0.007
# 超低端                                                          0.0940      0.429      0.219      0.827      -0.748       0.935
# 超高端                                                          3.0056      1.211      2.483      0.013       0.633       5.378
# 高端                                                           0.9114      0.578      1.576      0.115      -0.222       2.045
# ==============================================================================
# Omnibus:                   100865.575   Durbin-Watson:                   1.913
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         44653999.840
# Skew:                           9.739   Prob(JB):                         0.00
# Kurtosis:                     128.877   Cond. No.                     1.39e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC0)
# [2] The smallest eigenvalue is 3.58e-24. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
data = (
    user_info[[
        'age', 'male_flag', 'tenure', 'business_purpose_flag', 'smart_phone_flag',
        'govern_worker_flag', 'govern_cluster_flag', 'govern_industry_flag',
        'register_district', 'born_area', 'mean_communication_distance'
    ]]
    .join([
        # compare to 中端
        pd.get_dummies(user_info['phone_level'], drop_first=True),
        pd.get_dummies(user_info['register_district']),
        pd.get_dummies(user_info['born_area'])

    ])
)
formula = """\
    mean_communication_distance ~ age + male_flag + tenure + \
        business_purpose_flag + smart_phone_flag + govern_worker_flag + \
        govern_cluster_flag + govern_industry_flag + 低端 + 超低端 + 超高端 + \
        高端 + C(register_district) + C(born_area):C(register_district)\
"""
# (
#     smf.ols(
#         formula,
#         data=data,
#         drop_cols=['']
#     )
#     .fit(cov_type='HC0')
#     .summary()
# )
# Out:
# ['age',
#  'male_flag',
#  'tenure',
#  'business_purpose_flag',
#  'smart_phone_flag',
#  'govern_worker_flag',
#  'govern_cluster_flag',
#  'govern_industry_flag',
#  'register_district',
#  'born_area',
#  'mean_communication_distance',
#  '低端',
#  '超低端',
#  '超高端',
#  '高端',
#  '中江',
#  '什邡',
#  '广汉',
#  '德阳现业',
#  '绵竹',
#  '罗江',
#  '其他',
#  '凉山彝族自治州',
#  '已撤銷_眉山地区',
#  '甘孜藏族自治州',
#  '青海省海西蒙古族藏族自治州']
